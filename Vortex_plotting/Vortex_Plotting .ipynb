# %% [markdown]
# # To plot different quantities in prinstine vortex

# %%
import matplotlib.pyplot as plt
import numpy as np
# to control the tick architecture  (I have calledf extra stuff)
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)
# define the style, multiple styles can be used and the right overwrrite the left in conflict.
plt.style.use(["classic"])
import pandas as pd
# make a '2' pixel wide border of all the plots.
plt.rcParams['axes.linewidth'] = 1
# makes all latex into regular font type and removes default "italics"... very useful
plt.rcParams['mathtext.default'] = 'regular'
import numpy as np

# %%
# Mixture data  
number_density_percentage = [7.4/100, 22/100, 55/100, 99.64/100];  
Velocity_MP_Big = [[],[],[]];
Velocity_MP_Small = [[],[],[]];
Velocity_mean_Big = [[],[],[]];
Velocity_mean_Small = [[],[],[]];

# %%
# Pristine Fluorescent Data 
data_10um = pd.DataFrame();
data_7um = pd.DataFrame();
data_5um = pd.DataFrame();
ChamberAreaInPx = np.pi*600**2;
a = np.nan;
#~~~~~~~~~~~~~~~~~ 10um ~~~~~~~~~~~~~~~~~~~~~~~~~~~
AreaParticleInPx_10 = np.pi*(5/0.8621)**2;
particles_10 = np.array([12,17,22,32,45,51,58,66,86,99,142,144,226,600,720,900,1200,1400,2400]);
Mean_polarisation_130V_10 = np.array([0.0137, 0.0204, 0.414,0.504, 0.793,0.862,0.868, 0.867, 0.883, 0.886, 0.9, 0.898, 0.908, 0.914, 0.935, 0.956, 0.964, 0.967, 0.983]);
Mean_polarisation_150V_10 = np.array([0.0138, 0.0294, 0.782, 0.823, 0.821, 0.872, 0.869, 0.875, 0.891, 0.912, 0.928, 0.923, 0.925, 0.950, 0.952, 0.967, 0.967,0.968, 0.985]);
Mean_polarisation_170V_10 = np.array([0.0137, 0.0374, 0.821, 0.831, 0.828, 0.881, 0.889, 0.893, 0.909, 0.918, 0.933, 0.930, 0.929, 0.963, 0.968, 0.969, 0.968,0.967, 0.989]);
# push it onto a dataframe 


#~~~~~~~~~~~~~~~~~ 7um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
AreaParticleInPx_7 = np.pi*(3.5/0.8621)**2;
particles_7 = np.array([30, 64, 105, 258, 362, 540, 810, 920, 1210, 1260, 2530, 2180, 2690,3980, 3720]);
Mean_polarisation_102V_7 = np.array([0.057, 0.018, 0.011, 0.029, 0.071, 0.720, 0.807, 0.857, 0.881, 0.889, 0.930, 0.948, 0.948, 0.975, 0.951]);
Mean_polarisation_120V_7 = np.array([0.029, 0.021, 0.021, 0.019, 0.026, 0.789, 0.886, 0.882, 0.889, 0.899, 0.938, 0.948, 0.952, 0.976, 0.965]);
Mean_polarisation_130V_7 = np.array([    a,     a,     a,     a,     a, 0.821, 0.898,     a, 0.894, 0.903,     a,     a,     a,     a,     a]);
Mean_polarisation_140V_7 = np.array([0.020, 0.020, 0.013, 0.020, 0.031, 0.838, 0.898, 0.886, 0.896, 0.922, 0.936, 0.948, 0.953, 0.987, 0.965]);

AreaParticleInPx_7 = np.pi*(3.5/0.8621)**2;
particles_7 = np.array([30, 64, 105, 258, 362, 540, 810, 920, 1210, 1260, 2530, 2180, 2690,3980, 3720]);
Mean_polarisation_102V_7 = np.array([0.057, 0.018, 0.011, 0.029, 0.71, 0.720, 0.807, 0.857, 0.881, 0.889, 0.930, 0.948, 0.948, 0.975, 0.951]);
Mean_polarisation_120V_7 = np.array([0.029, 0.021, 0.021, 0.019, 0.26, 0.789, 0.886, 0.882, 0.889, 0.899, 0.938, 0.948, 0.952, 0.976, 0.965]);
Mean_polarisation_130V_7 = np.array([    a,     a,     a,     a,    a, 0.821, 0.898,     a, 0.894, 0.903,     a,     a,     a,     a,     a]);
Mean_polarisation_140V_7 = np.array([0.020, 0.020, 0.013, 0.020, 0.31, 0.838, 0.898, 0.886, 0.896, 0.922, 0.936, 0.948, 0.953, 0.987, 0.965]);

#~~~~~~~~~~~~~~~~~ 5um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
AreaParticleInPx_5 = np.pi*(2.5/0.8621)**2;
particles_5 = np.array([38, 133, 227, 308, 555, 650, 730, 860, 1470, 2050, 3000]);
Mean_polarisation_102V_5 = np.array([0.015, 0.083, 0.074, 0.044, 0.0480, 0.0527, 0.645, 0.716, 0.796, 0.816, 0.905]);
Mean_polarisation_120V_5 = np.array([0.023, 0.089, 0.044, 0.089, 0.0632, 0.0675, 0.744, 0.788, 0.843, 0.866, 0.926]);
Mean_polarisation_130V_5 = np.array([0.022, 0.082, 0.022, 0.031, 0.0666, 0.0696, 0.768, 0.801, 0.855, 0.871, 0.933]);
Mean_polarisation_140V_5 = np.array([0.045, 0.073, 0.012, 0.038, 0.0689, 0.0720, 0.793, 0.810, 0.863, 0.876, 0.951]);

AreaParticleInPx_5 = np.pi*(2.5/0.8621)**2;
particles_5 = np.array([38, 133, 227, 308, 555, 650, 730, 860, 1470, 2050, 3000]);
Mean_polarisation_102V_5 = np.array([0.015, 0.083, 0.074, 0.044, 0.480, 0.527, 0.645, 0.716, 0.796, 0.816, 0.905]);
Mean_polarisation_120V_5 = np.array([0.023, 0.089, 0.044, 0.089, 0.632, 0.675, 0.744, 0.788, 0.843, 0.866, 0.926]);
Mean_polarisation_130V_5 = np.array([0.022, 0.082, 0.022, 0.031, 0.666, 0.696, 0.768, 0.801, 0.855, 0.871, 0.933]);
Mean_polarisation_140V_5 = np.array([0.045, 0.073, 0.012, 0.038, 0.689, 0.720, 0.793, 0.810, 0.863, 0.876, 0.951]);

# %%
# Now you need to plot the data 
fig, ax = plt.subplots(4, figsize = (8,11),  constrained_layout=True)

ax[0].xaxis.set_minor_locator(AutoMinorLocator())
ax[0].yaxis.set_minor_locator(AutoMinorLocator())
ax[0].tick_params(which='both', width=1)
ax[0].tick_params(which='major', length=7)
ax[0].tick_params(which='minor', length=4, color='k',direction = "in")
ax[0].margins(0.05,);
ax[0].set_yticks([0,0.2,0.4,0.6,0.8,1]);

ax[0].set_ylabel(r'<$\pi_{\varphi}$>')
ax[0].set_xlabel("number density (#/$px^2$)");


#~~~~~~~~~~~~~~~~~~~~~~~~ 7um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[0].plot(particles_7/ChamberAreaInPx,Mean_polarisation_102V_7, label = " 7$\mu$m 102V", color = "yellow",linestyle = ":", marker = "*", markersize = 16);
ax[0].plot(particles_7/ChamberAreaInPx,Mean_polarisation_120V_7, label = " 7$\mu$m 120V", color = "green",linestyle = ":", marker = "*", markersize = 16);
ax[0].plot(particles_7/ChamberAreaInPx,Mean_polarisation_130V_7, label = " 7$\mu$m 130V", color = "blue" ,linestyle = ":", marker = "*", markersize = 16);
ax[0].plot(particles_7/ChamberAreaInPx,Mean_polarisation_140V_7, label = " 7$\mu$m 140V", color = "red"  ,linestyle = ":", marker = "*", markersize = 16);

#~~~~~~~~~~~~~~~~~~~~~~~~ 5um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[0].plot(particles_5/ChamberAreaInPx,Mean_polarisation_102V_5, label = " 5$\mu$m 102V", color = "yellow",linestyle = ":", marker = "^", markersize = 10);
ax[0].plot(particles_5/ChamberAreaInPx,Mean_polarisation_120V_5, label = " 5$\mu$m 120V", color = "green",linestyle = ":", marker = "^", markersize = 10);
ax[0].plot(particles_5/ChamberAreaInPx,Mean_polarisation_130V_5, label = " 5$\mu$m 130V", color = "blue" ,linestyle = ":", marker = "^", markersize = 10);
ax[0].plot(particles_5/ChamberAreaInPx,Mean_polarisation_140V_5, label = " 5$\mu$m 140V", color = "red"  ,linestyle = ":", marker = "^", markersize = 10);

#~~~~~~~~~~~~~~~~~~~~~~~~ 10um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[0].plot(particles_10/ChamberAreaInPx,Mean_polarisation_170V_10, label = "10$\mu$m 170V", color = "red",linestyle = ":", marker = "o", markersize = 10);
ax[0].plot(particles_10/ChamberAreaInPx,Mean_polarisation_150V_10, label = "10$\mu$m 150V", color = "green",linestyle = ":", marker = "o", markersize = 10);
ax[0].plot(particles_10/ChamberAreaInPx,Mean_polarisation_130V_10, label = "10$\mu$m 130V", color = "blue",linestyle = ":", marker = "o", markersize = 10);


#~~~~~~~the legends~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[0].legend(numpoints = 1, loc='center left', fontsize = 8, ncol = 1, markerscale = 0.8,bbox_to_anchor=(1, 0.5));

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

ax[1].xaxis.set_minor_locator(AutoMinorLocator())
ax[1].yaxis.set_minor_locator(AutoMinorLocator())
ax[1].tick_params(which='both', width=1)
ax[1].tick_params(which='major', length=7)
ax[1].tick_params(which='minor', length=4, color='k',direction = "in")
ax[1].margins(0.05,);
ax[1].set_yticks([0,0.2,0.4,0.6,0.8,1]);
ax[1].set_ylabel(r'<$\pi_{\varphi}$>')
ax[1].set_xlabel("Area Fraction($\phi$)");


#~~~~~~~~~~~~~~~~~~~~~~~~ 7um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[1].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_102V_7, label = " 7$\mu$m  102V", color = "yellow",linestyle = ":", marker = "*", markersize = 16);
ax[1].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_120V_7, label = " 7$\mu$m  120V", color = "green",linestyle = ":", marker = "*", markersize = 16);
ax[1].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_130V_7, label = " 7$\mu$m  130V", color = "blue" ,linestyle = ":", marker = "*", markersize = 16);
ax[1].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_140V_7, label = " 7$\mu$m  140V", color = "red"  ,linestyle = ":", marker = "*", markersize = 16);

#~~~~~~~~~~~~~~~~~~~~~~~~ 5um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[1].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_102V_5, label = " 5$\mu$m  102V", color = "yellow",linestyle = ":", marker = "^", markersize = 10);
ax[1].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_120V_5, label = " 5$\mu$m  120V", color = "green",linestyle = ":", marker = "^", markersize = 10);
ax[1].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_130V_5, label = " 5$\mu$m  130V", color = "blue" ,linestyle = ":", marker = "^", markersize = 10);
ax[1].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_140V_5, label = " 5$\mu$m  140V", color = "red"  ,linestyle = ":", marker = "^", markersize = 10);

#~~~~~~~~~~~~~~~~~~~~~~~~ 10um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[1].plot(particles_10/ChamberAreaInPx*AreaParticleInPx_10,Mean_polarisation_170V_10, label = "10$\mu$m 170V", color = "red", linestyle = ":", marker = "o", markersize = 10);
ax[1].plot(particles_10/ChamberAreaInPx*AreaParticleInPx_10,Mean_polarisation_150V_10, label = "10$\mu$m 150V", color = "green",linestyle = ":", marker = "o", markersize = 10);
ax[1].plot(particles_10/ChamberAreaInPx*AreaParticleInPx_10,Mean_polarisation_130V_10, label = "10$\mu$m 130V", color = "blue",  linestyle = ":", marker = "o", markersize = 10);

# ~~~~the legends~~~~~~~~~~~~~~~~
ax[1].legend(numpoints = 1, loc='center left', fontsize = 8, ncol = 1, markerscale = 0.8,bbox_to_anchor=(1, 0.5));

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

ax[2].xaxis.set_minor_locator(AutoMinorLocator())
ax[2].yaxis.set_minor_locator(AutoMinorLocator())
ax[2].tick_params(which='both', width=1)
ax[2].tick_params(which='major', length=7)
ax[2].tick_params(which='minor', length=4, color='k',direction = "in")
ax[2].margins(0.05,);


ax[2].set_ylabel(r'<$\pi_{\varphi}$>')
ax[2].set_xlabel("number density (#/$px^2$)");


#~~~~~~~~~~~~~~~~~~~~~~~~ 7um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[2].plot(particles_7/ChamberAreaInPx,Mean_polarisation_102V_7, label = " 7$\mu$m 102V", color = "yellow",linestyle = ":", marker = "*", markersize = 16);
ax[2].plot(particles_7/ChamberAreaInPx,Mean_polarisation_120V_7, label = " 7$\mu$m 120V", color = "green",linestyle = ":", marker = "*", markersize = 16);
ax[2].plot(particles_7/ChamberAreaInPx,Mean_polarisation_130V_7, label = " 7$\mu$m 130V", color = "blue" ,linestyle = ":", marker = "*", markersize = 16);
ax[2].plot(particles_7/ChamberAreaInPx,Mean_polarisation_140V_7, label = " 7$\mu$m 140V", color = "red"  ,linestyle = ":", marker = "*", markersize = 16);

#~~~~~~~~~~~~~~~~~~~~~~~~ 5um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[2].plot(particles_5/ChamberAreaInPx,Mean_polarisation_102V_5, label = " 5$\mu$m 102V", color = "yellow",linestyle = ":", marker = "^", markersize = 10);
ax[2].plot(particles_5/ChamberAreaInPx,Mean_polarisation_120V_5, label = " 5$\mu$m 120V", color = "green",linestyle = ":", marker = "^", markersize = 10);
ax[2].plot(particles_5/ChamberAreaInPx,Mean_polarisation_130V_5, label = " 5$\mu$m 130V", color = "blue" ,linestyle = ":", marker = "^", markersize = 10);
ax[2].plot(particles_5/ChamberAreaInPx,Mean_polarisation_140V_5, label = " 5$\mu$m 140V", color = "red"  ,linestyle = ":", marker = "^", markersize = 10);
#~~~~~~~~~~~~~~~~~~~~~~~~ 10um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[2].plot(particles_10/ChamberAreaInPx,Mean_polarisation_170V_10, label = "10$\mu$m 170V", color = "red",linestyle = ":", marker = "o", markersize = 10);
ax[2].plot(particles_10/ChamberAreaInPx,Mean_polarisation_150V_10, label = "10$\mu$m 150V", color = "green",linestyle = ":", marker = "o", markersize = 10);
ax[2].plot(particles_10/ChamberAreaInPx,Mean_polarisation_130V_10, label = "10$\mu$m 130V", color = "blue",linestyle = ":", marker = "o", markersize = 10);

#~~~~~~~the legends~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[2].set_xlim([0,0.001]);
ax[2].set_yticks([0,0.2,0.4,0.6,0.8,1]);
ax[2].legend(numpoints = 1, loc='center left', fontsize = 8, ncol = 1, markerscale = 0.8,bbox_to_anchor=(1, 0.5));

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

ax[3].xaxis.set_minor_locator(AutoMinorLocator())
ax[3].yaxis.set_minor_locator(AutoMinorLocator())
ax[3].tick_params(which='both', width=1)
ax[3].tick_params(which='major', length=7)
ax[3].tick_params(which='minor', length=4, color='k',direction = "in")
ax[3].margins(0.05,)
ax[3].set_ylabel(r'<$\pi_{\varphi}$>')
ax[3].set_xlabel("Area Fraction($\phi$)");


#~~~~~~~~~~~~~~~~~~~~~~~~ 7um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[3].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_102V_7, label = " 7$\mu$m 102V", color = "yellow",linestyle = ":", marker = "*", markersize = 16);
ax[3].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_120V_7, label = " 7$\mu$m 120V", color = "green",linestyle = ":", marker = "*", markersize = 16);
ax[3].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_130V_7, label = " 7$\mu$m 130V", color = "blue" ,linestyle = ":", marker = "*", markersize = 16);
ax[3].plot(particles_7/ChamberAreaInPx*AreaParticleInPx_7,Mean_polarisation_140V_7, label = " 7$\mu$m 140V", color = "red"  ,linestyle = ":", marker = "*", markersize = 16);

#~~~~~~~~~~~~~~~~~~~~~~~~ 5um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[3].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_102V_5, label = " 5$\mu$m 102V", color = "yellow",linestyle = ":", marker = "^", markersize = 10);
ax[3].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_120V_5, label = " 5$\mu$m 120V", color = "green",linestyle = ":", marker = "^", markersize = 10);
ax[3].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_130V_5, label = " 5$\mu$m 130V", color = "blue" ,linestyle = ":", marker = "^", markersize = 10);
ax[3].plot(particles_5/ChamberAreaInPx*AreaParticleInPx_5,Mean_polarisation_140V_5, label = " 5$\mu$m 140V", color = "red"  ,linestyle = ":", marker = "^", markersize = 10);
#~~~~~~~~~~~~~~~~~~~~~~~~ 10um ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[3].plot(particles_10*AreaParticleInPx_10/ChamberAreaInPx,Mean_polarisation_170V_10, label = "10$\mu$m 170V", color = "red",linestyle = ":", marker = "o", markersize = 10);
ax[3].plot(particles_10*AreaParticleInPx_10/ChamberAreaInPx,Mean_polarisation_150V_10, label = "10$\mu$m 150V", color = "green",linestyle = ":", marker = "o", markersize = 10);
ax[3].plot(particles_10*AreaParticleInPx_10/ChamberAreaInPx,Mean_polarisation_130V_10, label = "10$\mu$m 130V", color = "blue",linestyle = ":", marker = "o", markersize = 10);
ax[3].set_xlim([0, 0.02])
#~~~~~~~the legends~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
ax[3].set_yticks([0,0.2,0.4,0.6,0.8,1]);
ax[3].legend(numpoints = 1, loc='center left', fontsize = 8, ncol = 1, markerscale = 0.8,bbox_to_anchor=(1, 0.5));
ax[3].set_xlim([0,0.02]);

plt.suptitle(r"Mean Polarization of 10$\mu$m, 7$\mu$m and 5$\mu$m Particles in Vortex", fontsize = 15 )
plt.savefig("Plots\Mean Polarisation vs density_dark.pdf",bbox_inches = 'tight', dpi = 500)
